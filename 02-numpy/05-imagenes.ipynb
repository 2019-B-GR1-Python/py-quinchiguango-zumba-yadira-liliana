# %%
#Importar numpy y scipy
import numpy as np
from scipy import ndimage
from scipy import misc

# %%
mapache = misc.face()
mapache
# Out:
# array([[[121, 112, 131],
#         [138, 129, 148],
#         [153, 144, 165],
#         ...,
#         [119, 126,  74],
#         [131, 136,  82],
#         [139, 144,  90]],
#
#        [[ 89,  82, 100],
#         [110, 103, 121],
#         [130, 122, 143],
#         ...,
#         [118, 125,  71],
#         [134, 141,  87],
#         [146, 153,  99]],
#
#        [[ 73,  66,  84],
#         [ 94,  87, 105],
#         [115, 108, 126],
#         ...,
#         [117, 126,  71],
#         [133, 142,  87],
#         [144, 153,  98]],
#
#        ...,
#
#        [[ 87, 106,  76],
#         [ 94, 110,  81],
#         [107, 124,  92],
#         ...,
#         [120, 158,  97],
#         [119, 157,  96],
#         [119, 158,  95]],
#
#        [[ 85, 101,  72],
#         [ 95, 111,  82],
#         [112, 127,  96],
#         ...,
#         [121, 157,  96],
#         [120, 156,  94],
#         [120, 156,  94]],
#
#        [[ 85, 101,  74],
#         [ 97, 113,  84],
#         [111, 126,  97],
# ...

# %%
mapache.shape
# Out:
# (768, 1024, 3)

# %%
type(mapache)
# Out:
# numpy.ndarray

# %%
# Para dibujar el mapache
import matplotlib.pyplot as plt

# %%
plt.imshow(mapache)
#plt.show
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-70-200ef2c8faa0> in <module>
# ----> 1 plt.imshow(zorro)
#       2 #plt.show
#
# NameError: name 'zorro' is not defined

# %%
plt.imshow(mapache[::-1])

# %%
plt.imshow(mapache[::-2]) # Mapache gordo y acostado

# %%
plt.imshow(mapache[::2])

# %%
plt.imshow(mapache*2)

# %%
plt.imshow(mapache[100:500, 450:900]) #Recortar su carita

# %%
plt.imshow(mapache[200:220, 200:220]) # Acercamiento

# %%
mapache_filtro = ndimage.gaussian_filter(mapache, sigma=3)
plt.imshow(mapache_filtro)

# %%
#Usar reshape y poner en cada una un pedazo, en consola ingresar las pocisiones a mover
pieza1, pieza2, pieza3, pieza4 = np.hsplit(mapache, 4)

# %%
plt.imshow(pieza1)

# %%
plt.imshow(pieza2)
